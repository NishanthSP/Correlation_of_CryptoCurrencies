# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Read the dataset

# %%
btc = pd.read_csv('data/BTC.csv')
ada = pd.read_csv('data/ADA.csv')
eth = pd.read_csv('data/ETH.csv')
ltu = pd.read_csv('data/LTU.csv')
neo = pd.read_csv('data/NEO.csv')
xlm = pd.read_csv('data/XLM.csv')
xrp = pd.read_csv('data/XRP.csv')

# %%
btc = btc.iloc[120:486]
# Out:
#              unix              date    symbol      open      high       low  \
# 120  1.609200e+12  29-12-2020 00:00  BTC/USDT  27079.42  27410.00  25880.00
# 121  1.609110e+12  28-12-2020 00:00  BTC/USDT  26281.54  27500.00  26101.00
# 122  1.609030e+12  27-12-2020 00:00  BTC/USDT  26493.40  28422.00  25700.00
# 123  1.608940e+12  26-12-2020 00:00  BTC/USDT  24712.47  26867.03  24500.00
# 124  1.608850e+12  25-12-2020 00:00  BTC/USDT  23728.99  24789.86  23433.60
# ..            ...               ...       ...       ...       ...       ...
# 481  1.578010e+12  03-01-2020 00:00  BTC/USDT   6965.49   7405.00   6871.04
# 482  1.577920e+12  02-01-2020 00:00  BTC/USDT   7200.77   7212.50   6924.74
# 483  1.577840e+12  01-01-2020 00:00  BTC/USDT   7195.24   7255.00   7175.15
# 484  1.577750e+12  31-12-2019 00:00  BTC/USDT   7246.00   7320.00   7145.01
# 485  1.577660e+12  30-12-2019 00:00  BTC/USDT   7388.43   7408.24   7220.00
#
#         close    Volume BTC   Volume USDT  tradecount
# 120  27385.00   69411.59261  1.851617e+09   1605166.0
# 121  27079.41   79721.74250  2.151807e+09   1508204.0
# 122  26281.66  148455.58620  4.028929e+09   2438493.0
# 123  26493.39   97806.51339  2.496533e+09   1735574.0
# 124  24712.47   79519.94357  1.919766e+09   1504426.0
# ..        ...           ...           ...         ...
# 481   7344.96   68428.50045  4.950986e+08    519854.0
# 482   6965.71   31951.48393  2.259823e+08    302667.0
# 483   7200.85   16792.38817  1.212145e+08    194010.0
# 484   7195.23   25954.45353  1.875184e+08    251976.0
# 485   7246.00   29605.91178  2.165089e+08    279033.0
#
# [366 rows x 10 columns]
